# %%
pip install openai langchain tiktoken

# %%
import os
import json
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
embeddings_model = OpenAIEmbeddings()

# %%
for dir_num in range(50):
  dir_path = f"/content/gdrive/MyDrive/Audio Retrieval/data/convo{dir_num}"
  filepath = f"{dir_path}/transcription.txt"
  with open(filepath, "r") as file:
    transcript = file.read()

  emb_vector = embeddings_model.embed_query(transcript)
  embeddings_path = f"{dir_path}/embeddings.json"
  with open(embeddings_path, "w") as file:
    file.write(json.dumps(emb_vector))

  time.sleep(90)
